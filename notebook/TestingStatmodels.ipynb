# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X_df = pd.DataFrame(X, columns = [f'Feature_{i+1}' for i in range(X.shape[1])])
X_df
# Out:
#      Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0     0.038076   0.050680   0.061696   0.021872  -0.044223  -0.034821
# 1    -0.001882  -0.044642  -0.051474  -0.026328  -0.008449  -0.019163
# 2     0.085299   0.050680   0.044451  -0.005670  -0.045599  -0.034194
# 3    -0.089063  -0.044642  -0.011595  -0.036656   0.012191   0.024991
# 4     0.005383  -0.044642  -0.036385   0.021872   0.003935   0.015596
# ..         ...        ...        ...        ...        ...        ...
# 437   0.041708   0.050680   0.019662   0.059744  -0.005697  -0.002566
# 438  -0.005515   0.050680  -0.015906  -0.067642   0.049341   0.079165
# 439   0.041708   0.050680  -0.015906   0.017293  -0.037344  -0.013840
# 440  -0.045472  -0.044642   0.039062   0.001215   0.016318   0.015283
# 441  -0.045472  -0.044642  -0.073030  -0.081413   0.083740   0.027809
#
#      Feature_7  Feature_8  Feature_9  Feature_10
# 0    -0.043401  -0.002592   0.019907   -0.017646
# ...

# %%
col= X_df.columns
for index in col:
     print(index)
# Out:
# Feature_1
# Feature_2
# Feature_3
# Feature_4
# Feature_5
# Feature_6
# Feature_7
# Feature_8
# Feature_9
# Feature_10

# %%
y_df = pd.DataFrame(y, columns = ['Target'])
y_df
# Out:
#      Target
# 0     151.0
# 1      75.0
# 2     141.0
# 3     206.0
# 4     135.0
# ..      ...
# 437   178.0
# 438   104.0
# 439   132.0
# 440   220.0
# 441    57.0
#
# [442 rows x 1 columns]

# %%
df = pd.concat([X_df, y_df], axis = 1) 
df
# Out:
#      Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0     0.038076   0.050680   0.061696   0.021872  -0.044223  -0.034821
# 1    -0.001882  -0.044642  -0.051474  -0.026328  -0.008449  -0.019163
# 2     0.085299   0.050680   0.044451  -0.005670  -0.045599  -0.034194
# 3    -0.089063  -0.044642  -0.011595  -0.036656   0.012191   0.024991
# 4     0.005383  -0.044642  -0.036385   0.021872   0.003935   0.015596
# ..         ...        ...        ...        ...        ...        ...
# 437   0.041708   0.050680   0.019662   0.059744  -0.005697  -0.002566
# 438  -0.005515   0.050680  -0.015906  -0.067642   0.049341   0.079165
# 439   0.041708   0.050680  -0.015906   0.017293  -0.037344  -0.013840
# 440  -0.045472  -0.044642   0.039062   0.001215   0.016318   0.015283
# 441  -0.045472  -0.044642  -0.073030  -0.081413   0.083740   0.027809
#
#      Feature_7  Feature_8  Feature_9  Feature_10  Target
# 0    -0.043401  -0.002592   0.019907   -0.017646   151.0
# ...

# %%
X = df.drop('Target', axis = 1)
y = df.Target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   test_size = .3, # 30% of data for testing
                                                   shuffle = True, # Shuffling values
                                                   random_state = 42)

# %%
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %%
X_train
# Out:
#      const  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 225    1.0   0.030811   0.050680   0.032595   0.049415  -0.040096  -0.043589
# 412    1.0   0.074401  -0.044642   0.085408   0.063187   0.014942   0.013091
# 118    1.0  -0.056370   0.050680  -0.010517   0.025315   0.023198   0.040022
# 114    1.0   0.023546  -0.044642   0.110198   0.063187   0.013567  -0.032942
# 364    1.0   0.001751   0.050680  -0.006206  -0.019442  -0.009825   0.004949
# ..     ...        ...        ...        ...        ...        ...        ...
# 106    1.0  -0.096328  -0.044642  -0.076264  -0.043542  -0.045599  -0.034821
# 270    1.0   0.005383   0.050680   0.030440   0.083844  -0.037344  -0.047347
# 348    1.0   0.030811  -0.044642  -0.020218  -0.005670  -0.004321  -0.029497
# 435    1.0  -0.012780  -0.044642  -0.023451  -0.040099  -0.016704   0.004636
# 102    1.0  -0.092695  -0.044642   0.028284  -0.015999   0.036958   0.024991
#
# ...

# %%
X_train
# Out:
#      const  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 225    1.0   0.030811   0.050680   0.032595   0.049415  -0.040096  -0.043589
# 412    1.0   0.074401  -0.044642   0.085408   0.063187   0.014942   0.013091
# 118    1.0  -0.056370   0.050680  -0.010517   0.025315   0.023198   0.040022
# 114    1.0   0.023546  -0.044642   0.110198   0.063187   0.013567  -0.032942
# 364    1.0   0.001751   0.050680  -0.006206  -0.019442  -0.009825   0.004949
# ..     ...        ...        ...        ...        ...        ...        ...
# 106    1.0  -0.096328  -0.044642  -0.076264  -0.043542  -0.045599  -0.034821
# 270    1.0   0.005383   0.050680   0.030440   0.083844  -0.037344  -0.047347
# 348    1.0   0.030811  -0.044642  -0.020218  -0.005670  -0.004321  -0.029497
# 435    1.0  -0.012780  -0.044642  -0.023451  -0.040099  -0.016704   0.004636
# 102    1.0  -0.092695  -0.044642   0.028284  -0.015999   0.036958   0.024991
#
# ...

# %%
X_train.shape
# Out:
# (309, 11)

# %%
b = np.array([[4, 5, 6, 5, 2],[12, 2, 3, 4, 6],[11, 2, 3, 4, 8],[14, 2, 3, 4, 8]])
v1= ["Previous Scores", "Extracurricular Activities", "Sleep Hours", "Sample Question Papers Practiced"]
v2= ["Hours Studied", "Previous Scores", "Extracurricular Activities", "Sleep Hours", "Sample Question Papers Practiced"]
 
fig, ax = plt.subplots()
ax.set_xticks(np.arange(len(v2)), labels=v2)
ax.set_yticks(np.arange(len(v1)), labels=v1)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
im = ax.imshow(b)
plt.show()
